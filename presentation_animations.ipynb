# %%
import manim as mn
from manim import *
import json
import numpy as np

config.media_dir = "./presentation_vids"
config.media_width = "75%"
config.verbosity = "WARNING"

print(mn.__version__)
# Out:
# 0.20.1

# %% [markdown]
# ## ANOVA

# %%
# %%manim -qm GraphPlot
# class GraphPlot(Scene):
#     def construct(self):
#         with open('data/corp_avg_dict.json', 'r') as infile:
#             data = json.load(infile)
#         colors = [BLUE, RED, GREEN, YELLOW, PURPLE]
#
#         plot_axes = Axes(
#             x_range=[1, 3, 1],
#             y_range=[0, 7, 1],
#             x_length=9,
#             y_length=5.5,
#             axis_config={"font_size": 24},
#             x_axis_config={
#                 "scaling": LogBase(base=10),
#             },
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 8, 1),
#             },
#             tips=False,
#         )
#
#         custom_ticks = [10, 25, 50, 100, 250, 500]
#         tick_labels = VGroup(*[
#             MathTex(str(v), font_size=20).next_to(
#                 plot_axes.c2p(v, 0), DOWN, buff=0.2
#             )
#             for v in custom_ticks
#         ])
#
#         title = Title('Aggregated Performance by Corpus', include_underline=False, font_size=40)
#         y_label = plot_axes.get_y_axis_label("Correct\ Answers", edge=LEFT, direction=LEFT)
#         y_label.rotate(PI/2)
#         y_label.shift(LEFT * 0.5)
#         x_label = plot_axes.get_x_axis_label("File\ Set\ Size", edge=DOWN)
#         x_label.shift(DOWN * 0.9)
#         x_label.shift(LEFT * 2)
#         plot_labels = VGroup(x_label, y_label)
#
#         lines = VGroup()
#         for (label, points), color in zip(data.items(), colors):
#             xs = [int(k) for k in points.keys()]
#             ys = list(points.values())
#             line = plot_axes.plot_line_graph(
#                 x_values=xs,
#                 y_values=ys,
#                 line_color=color,
#                 add_vertex_dots=True,
#                 vertex_dot_radius=0.05,
#             )
#             lines.add(line)
#
#         legend_items = VGroup()
#         for (label, _), color in zip(data.items(), colors):
#             dot = Dot(color=color, radius=0.1)
#             text = Text(label, font_size=20, color=color)
#             text.next_to(dot, RIGHT, buff=0.15)
#             item = VGroup(dot, text)
#             legend_items.add(item)
#
#         legend_items.arrange(DOWN, aligned_edge=LEFT, buff=0.2)
#         legend_box = SurroundingRectangle(legend_items, color=WHITE, buff=0.2)
#         legend = VGroup(legend_box, legend_items)
#         legend.to_corner(UR, buff=0.5)
#
#         self.play(Write(title))
#         self.play(Create(plot_axes), Create(plot_labels), Create(tick_labels), Create(legend), run_time=5)
#         self.play(Create(lines), run_time=10)
#         self.wait()
# Out:
# <string>:31: SyntaxWarning: invalid escape sequence '\ '
# <string>:34: SyntaxWarning: invalid escape sequence '\ '
# Manim Community v0.20.1
# <video src="presentation_vids/jupyter/GraphPlot@2026-03-04@15-08-09.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
np.random.seed(42)

# Cluster 1: centered at (2, 3)
c1_x = np.random.normal(loc=2, scale=0.5, size=30)
c1_y = np.random.normal(loc=3, scale=0.5, size=30)

# Cluster 2: centered at (5, 3)
c2_x = np.random.normal(loc=5, scale=0.5, size=30)
c2_y = np.random.normal(loc=3, scale=0.5, size=30)

print(c1_x, c1_y)
print(c2_x, c2_y)
# Out:
# [2.24835708 1.93086785 2.32384427 2.76151493 1.88292331 1.88293152
#  2.78960641 2.38371736 1.76526281 2.27128002 1.76829115 1.76713512
#  2.12098114 1.04335988 1.13754108 1.71885624 1.49358444 2.15712367
#  1.54598796 1.29384815 2.73282438 1.88711185 2.0337641  1.28762591
#  1.72780864 2.05546129 1.42450321 2.18784901 1.69968066 1.85415313] [2.69914669 3.92613909 2.99325139 2.47114454 3.41127246 2.38957818
#  3.1044318  2.02016494 2.33590698 3.09843062 3.36923329 3.08568414
#  2.94217586 2.84944815 2.260739   2.6400779  2.76968061 3.52856111
#  3.17180914 2.11847992 3.16204198 2.80745886 2.661539   3.30583814
#  3.51549976 3.46564006 2.58039124 2.84539381 3.16563172 3.48777256]
# [4.76041288 4.90717051 4.44683251 4.40189669 5.40626291 5.67812001
#  4.96399494 5.50176645 5.18081801 4.67744012 5.1806978  5.76901828
#  4.98208698 5.78232183 3.69012745 5.41095125 5.04352353 4.85049632
#  5.04588039 4.00621554 4.89016406 5.17855629 5.73894702 4.74086489
#  4.5957532  4.74912148 5.45770106 5.16437555 4.7351199  5.25663372] [3.04853877 3.4843225  2.64897345 2.83616893 2.80394592 2.26824253
#  3.14806014 3.13052764 3.00255673 2.88270643 2.29231463 2.78967734
#  2.82864274 2.59886137 2.91935714 3.20202543 3.94309295 3.08728891
#  3.1287752  2.96277704 2.04061439 2.98674306 3.0301151  4.23162106
#  2.90381952 3.15077367 2.98264412 2.41566098 3.57141141 3.37596652]

# %%
# %%manim -qm PlotExample
#
# class PlotExample(Scene):
#     def construct(self):
#         plot_axes = Axes(
#             x_range=[0, 7, 1],
#             y_range=[0, 6, 1],
#             x_length=9,
#             y_length=5.5,
#             axis_config={"font_size": 24},
#             tips=False,
#         )
#
#         cluster1_dots = VGroup(*[
#             Dot(plot_axes.c2p(x, y), color=BLUE, radius=0.05)
#             for x, y in zip(c1_x, c1_y)
#         ])
#
#         cluster2_dots = VGroup(*[
#             Dot(plot_axes.c2p(x, y), color=RED, radius=0.05)
#             for x, y in zip(c2_x, c2_y)
#         ])
#
#         self.play(Create(cluster1_dots), Create(cluster2_dots), run_time=10)
#         self.play(
#     cluster1_dots.animate.shift(
#         plot_axes.c2p(3.5, 3) - plot_axes.c2p(c1_x.mean(), c1_y.mean())
#     ),
#     cluster2_dots.animate.shift(
#         plot_axes.c2p(3.5, 3) - plot_axes.c2p(c2_x.mean(), c2_y.mean())
#     ),
#     run_time=3
# )
#         self.wait()
# Out:
# Manim Community v0.20.1
# <video src="presentation_vids/jupyter/PlotExample@2026-03-04@15-51-56.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm PlotExample
#
# class PlotExample(Scene):
#     def construct(self):
#         plot_axes = Axes(
#             x_range=[0, 7, 1],
#             y_range=[0, 6, 1],
#             x_length=9,
#             y_length=5.5,
#             axis_config={"font_size": 24},
#             tips=False,
#         )
#
#         cluster1_dots = VGroup(*[
#             Dot(plot_axes.c2p(x, y), color=BLUE, radius=0.05)
#             for x, y in zip(c1_x, c1_y)
#         ])
#
#         cluster2_dots = VGroup(*[
#             Dot(plot_axes.c2p(x, y), color=RED, radius=0.05)
#             for x, y in zip(c2_x, c2_y)
#         ])
#
#
#         f_formula = MathTex(r"F = \frac{}{}", font_size=36)
#         f_formula.to_edge(UP, buff=1.5) ; f_formula.shift(LEFT*3)
#
#         numerator = MathTex(r"variation\ between\ groups", font_size=36)
#         denominator = MathTex(r"variation\ within\ groups", font_size=36)
#         fraction_line = Line(LEFT, RIGHT, color=WHITE).scale(2)
#
#         fraction_line.next_to(f_formula, RIGHT, buff=0.7)
#         numerator.next_to(fraction_line, UP, buff=0.2)
#         denominator.next_to(fraction_line, DOWN, buff=0.2)
#
#         original1 = cluster1_dots.get_center()
#         original2 = cluster2_dots.get_center()
#
#         self.play(Create(cluster1_dots), Create(cluster2_dots), run_time=5)
#         self.play(Write(fraction_line), Write(f_formula), Write(numerator), Write(denominator), run_time=5)
#         self.play(cluster1_dots.animate.shift(plot_axes.c2p(3.5, 3) - plot_axes.c2p(c1_x.mean(), c1_y.mean())),
#                     cluster2_dots.animate.shift(plot_axes.c2p(3.5, 3) - plot_axes.c2p(c2_x.mean(), c2_y.mean())),
#                     numerator.animate.scale(1.5),
#                     run_time=3
#                 )
#         self.play(cluster1_dots.animate.shift(plot_axes.c2p(2, 3) + plot_axes.c2p(c1_x.mean(), c1_y.mean())),
#                     cluster2_dots.animate.shift(plot_axes.c2p(5.5, 3) + plot_axes.c2p(c2_x.mean(), c2_y.mean())),
#                     denominator.animate.scale(1.5),
#                     numerator.animate.scale(0.7),
#                     run_time=3
#                 )
#         self.play(cluster1_dots.animate.move_to(original1),
#                     cluster2_dots.animate.move_to(original2),
#                     denominator.animate.scale(0.7),
#                     run_time=3
#                 )
#         self.wait()
# Out:
# Manim Community v0.20.1
# <video src="presentation_vids/jupyter/PlotExample@2026-03-04@16-37-23.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm PlotExample
#
# class PlotExample(Scene):
#     def construct(self):
#         plot_axes = Axes(
#             x_range=[0, 7, 1],
#             y_range=[0, 6, 1],
#             x_length=9,
#             y_length=5.5,
#             axis_config={"font_size": 24},
#             tips=False,
#         )
#
#         cluster1_dots = VGroup(*[
#             Dot(plot_axes.c2p(x, y), color=BLUE, radius=0.05)
#             for x, y in zip(c1_x, c1_y)
#         ])
#
#         cluster2_dots = VGroup(*[
#             Dot(plot_axes.c2p(x, y), color=RED, radius=0.05)
#             for x, y in zip(c2_x, c2_y)
#         ])
#
#
#         f_formula = MathTex(r"F = \frac{}{}", font_size=36)
#         f_formula.to_edge(UP, buff=1.5) ; f_formula.shift(LEFT*3)
#
#         numerator = MathTex(r"variation\ between\ groups", font_size=36)
#         denominator = MathTex(r"variation\ within\ groups", font_size=36)
#         fraction_line = Line(LEFT, RIGHT, color=WHITE).scale(2)
#
#         fraction_line.next_to(f_formula, RIGHT, buff=0.7)
#         numerator.next_to(fraction_line, UP, buff=0.2)
#         denominator.next_to(fraction_line, DOWN, buff=0.2)
#
#         original1 = cluster1_dots.get_center()
#         original2 = cluster2_dots.get_center()
#
#         self.add(cluster1_dots, cluster2_dots)
#         self.add(fraction_line, f_formula,numerator, denominator)
#         self.play(FadeOut(cluster2_dots),
#                 FadeOut(f_formula),
#                 FadeOut(fraction_line),
#                 FadeOut(numerator),
#                 FadeOut(denominator),
#                 cluster1_dots.animate.shift(plot_axes.c2p(3.5, 3) - plot_axes.c2p(c1_x.mean(), c1_y.mean())),
#                 run_time = 3)
#         self.play(cluster1_dots.animate.scale(3), run_time=3)
#         self.wait()
# Out:
# Manim Community v0.20.1
# <video src="presentation_vids/jupyter/PlotExample@2026-03-04@16-54-51.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
